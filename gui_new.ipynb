# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import r2_score,mean_squared_error
#%%
import warnings
warnings.filterwarnings('ignore')

data=pd.read_csv(r'C:/Users/TECH - PLANET/Downloads/Salary_Data.csv')
data.describe()
# %matplotlib inline

# %%
#%%
plt.figure(figsize=(3,3))
sns.pairplot(data,x_vars=["YearsExperience"],y_vars=["Salary"],size=7,kind="scatter")
plt.xlabel("years")
plt.ylabel("salary")
plt.title("salary prediction")
plt.show()

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,1].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.8,random_state=10)

# %%
my_model=LinearRegression()
my_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#%%
y_pred = my_model.predict(x_test)
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_test, y_pred, color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
#%%

# %%
#%%
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, my_model.predict(x_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
# Plotting the actual and predicted values

c = [i for i in range(1,len(y_test)+1)]
plt.plot(c,y_test,color='r',linestyle='-')
plt.plot(c,y_pred,color='b',linestyle='-')
plt.xlabel('Salary')
plt.ylabel('index')
plt.title('Prediction')
plt.show()

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
# calculate Mean square error
mse = mean_squared_error(y_test,y_pred)
# Calculate R square vale
rsq = r2_score(y_test,y_pred)
print('mean squared error :',mse)
print('r square :',rsq)
#%%
# Intecept and coeff of the line
print('Intercept of the model:',my_model.intercept_)
print('Coefficient of the line:',my_model.coef_)

y_hat = 9357 * 7 +  26089 
print(y_hat)
# Out:
# mean squared error : 38525975.63126316
# r square : 0.9490289127347824
# Intercept of the model: 24426.984856920164
# Coefficient of the line: [9278.74846899]
# 91588

# %%
x=int(input("pls inter your years experience"))
y_hat = 9357 * x +  26089 
y_hat
# Out:
# 72874

# %%
import tkinter as tk
root=tk.Tk()
root.title("Salary prediction App")
def add_to_list():
    x=entry.get()
    if x.isdigit():
        x=int(x)
        y_hat = 9357 * x +  26089 
        text_list.insert(tk.END,f"No_Of_Years:{x}")
        text_list.insert(tk.END,f"Predected_Salary:{y_hat}")
    else:
        text_list.insert(tk.END,"invalid_input")
        
        entry.delete(0,tk.END)
frame=tk.Frame(root)
frame.grid(row=0, column=1)
entry=tk.Entry(frame)
entry.grid(row=0,column=2)
entry_btn=tk.Button(frame,text="Years Of Experiance",command=add_to_list)
entry_btn.grid(row=0,column=3)
text_list=tk.Listbox(frame,width=60,height=30,font=("Time New Roman",14))
text_list.grid(row=0,column=4)


root.mainloop()
